# %% [markdown]
# # Analyzing text
#
#
# #### AN IMPORTANT ANNOUNCEMENT
# Step 3 of the mini-project (downloading the dataset), which is further down in this notebook, takes a long time. You may want to do that step when you are taking a break from the rest of the notebook or, alternatively, you can download the file outside of this Python notebook
#
# <img src="http://zacharski.org/files/courses/cs419/tiles.jpg" width="500"/>
#
# So far we have been dealing with **structured data**. Structured data is ... well ... structured. This means that an instance of our data has nice attributes that can be represented in a DataFrame or a table:
#
# make | mpg | cylinders | HP | 0-60 |
# :---- | :---: | :---: | :---: | :---: |
# Fiat | 38 | 4 | 157   | 6.9
# Ford F150 | 19 | 6 | 386 | 6.3
# Mazda 3 | 37 | 4 | 155 |  7.5
# Ford Escape | 27 | 4 | 245 | 7.1
# Kia Soul | 31 | 4 | 164 | 8.5
#
# The majority of data in the world is **unstructured**. Take text for example. Suppose I have a corpus of twitter posts from President Trump and the Dalai Lama and my goal is to create a classifier that takes a tweet and tells me if it was produced by Trump or the Dalai Lama:
#
# *The purpose of education is to build a happier society, we need a more holistic approach that promotes the practice of love and compassion.*
#
# *How low has President Obama gone to tapp my phones during the very sacred election*
#
# We might consider  the columns of a table to be things like *first word of the tweet*, *second word of the tweet* and so on:
#
#
# id | word 1 | word 2 | word 3 | word 4 |word 5 |word 6 | ... |
# :---- | :---: | :---: | :---: | :---: | :---: |:---: | :---:
# 1 | The | purpose | of   | education |is | to | ...
# 2 | How | low | has |President | Obama | gone | ...
#
# So we would be counting how many times the word *President* occurred as the fourth word of a tweet. **But that would be the wrong way to go**.
#
# A more common way to represent text is to treat the text as an unordered set of words, which is called the **bag of words** approach.
#
# ## Bag of words
# <img src="http://zacharski.org/files/courses/cs419/BagofWords.jpg" width="350"/>
#
# With the bag of words approach we count word occurrences and the features (what we might think of as columns) are the words. For example, we take a bunch of Trump tweets and count word occurrences and do the same with the Dalai Lama tweets and we might get something like:
#
# id | a | the | compassion | love |sad |fake | ... |
# ---- | :---: | :---: | :---: | :---: | :---: |:---: |:---: |
# Trump | 42 | 27 | 1   | 5 |311 | 227 | ...
# Dalai Lama | 72 | 103 | 176 |159 | 5 | 1 | ...
#
# So, for example, Trump has used the word *compassion* once in all his tweets  but the Dalai Lama used it 103 times (this data is made-up).
#
# This 'bag of words' allows us to use the classification methods we have been using.
#
# Converting **unstructured** text to something **structured** is a multistep process. Let's learn the bits before putting it together. And we will start with the last step first-- creating the bag of words.
#
# ## We are going to need a vectorizer.
# We don't know what that is yet, but let's import the library:

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# # now create a vectorizer

# %%
vectorizer = CountVectorizer()

# %% [markdown]
# Now we will create some text:

# %%
trump1 = "How low has President Obama gone to tapp my phones during the very sacred election process. This is Nixon/Watergate. Obama bad (or sick) guy! Sad"
trump2 = "Our wonderful new Healthcare Bill is now out for review and negotiation. ObamaCare is a complete and total disaster - is imploding fast! Sad"
trump3 = "Don't let the FAKE NEWS tell you that there is big infighting in the Trump Admin. We are getting along great, and getting major things done!"
trump4 = "Russia talk is FAKE NEWS put out by the Dems, and played up by the media, in order to mask the big election defeat and the illegal leaks! Sad"
dalaiLama1 = "The purpose of education is to build a happier society, we need a more holistic approach that promotes the practice of love and compassion."
dalaiLama2 = "Be a kind and compassionate person. This is the inner beauty that is a key factor to making a better world."
dalaiLama3 = "If our goal is a happier, more peaceful world in the future, only education will bring change."
dalaiLama4 = "Love and compassion are important, because they strengthen us. This is a source of hope"
tinyCorpus = [trump1, trump2, trump3, trump4, dalaiLama1, dalaiLama2, dalaiLama3, dalaiLama4]
tinyCorpus
# Out:
# ['How low has President Obama gone to tapp my phones during the very sacred election process. This is Nixon/Watergate. Obama bad (or sick) guy! Sad',
#  'Our wonderful new Healthcare Bill is now out for review and negotiation. ObamaCare is a complete and total disaster - is imploding fast! Sad',
#  "Don't let the FAKE NEWS tell you that there is big infighting in the Trump Admin. We are getting along great, and getting major things done!",
#  'Russia talk is FAKE NEWS put out by the Dems, and played up by the media, in order to mask the big election defeat and the illegal leaks! Sad',
#  'The purpose of education is to build a happier society, we need a more holistic approach that promotes the practice of love and compassion.',
#  'Be a kind and compassionate person. This is the inner beauty that is a key factor to making a better world.',
#  'If our goal is a happier, more peaceful world in the future, only education will bring change.',
#  'Love and compassion are important, because they strengthen us. This is a source of hope']

# %% [markdown]
# ## fit the corpus
# We have used `fit` before so this looks similar to what we have done but the results are a bit different.

# %%
vectorizer.fit(tinyCorpus)
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %% [markdown]
# When we use the fit method, the vectorizer goes through the corpus, collects all the unique words and gives them an index number.
# We can find out the index of a word by using the `.vocabulary_.get` function

# %%
print(vectorizer.vocabulary_.get('love'))
print(vectorizer.vocabulary_.get('obama'))
# Out:
# 55
# 69

# %% [markdown]
# so the word *love* has index 55 and *Obama* has index 69.
# Now let's create the bag of words:

# %%
text = vectorizer.transform(tinyCorpus)
print(text)
# Out:
#   (0, 5)	1
#   (0, 24)	1
#   (0, 26)	1
#   (0, 34)	1
#   (0, 36)	1
#   (0, 38)	1
#   (0, 42)	1
#   (0, 50)	1
#   (0, 56)	1
#   (0, 62)	1
#   (0, 67)	1
#   (0, 69)	2
#   (0, 73)	1
#   (0, 79)	1
#   (0, 82)	1
#   (0, 83)	1
#   (0, 89)	1
#   (0, 90)	1
#   (0, 91)	1
#   (0, 96)	1
#   (0, 99)	1
#   (0, 103)	1
#   (0, 104)	1
#   (0, 109)	1
#   (0, 110)	1
#   :	:
#   (6, 37)	1
#   (6, 43)	1
#   (6, 47)	1
#   (6, 50)	1
#   (6, 61)	1
#   (6, 72)	1
#   (6, 75)	1
#   (6, 77)	1
#   (6, 99)	1
#   (6, 112)	1
#   (6, 114)	1
#   (7, 2)	1
#   (7, 4)	1
#   (7, 8)	1
#   (7, 16)	1
#   (7, 41)	1
#   (7, 46)	1
#   (7, 50)	1
#   (7, 55)	1
#   (7, 71)	1
#   (7, 93)	1
#   (7, 94)	1
#   (7, 101)	1
#   (7, 103)	1
#   (7, 108)	1

# %% [markdown]
# That `print` was unnecessary but it does show the format of the text. So
#
#     (0, 69)	2
#
# Means that in tweet 0, the word with index 69 (*Obama*) occurred twice.
#
# This `(0, 69)` is a sparse matrix representation. Before talking about that representation, let's review the DataFrame method we have been using. Suppose we have a large email corpus. The columns of our table represent all the unique words in the corpus. We have columns for typical words like *Obama*, *compassion*, and *mess*. And we also have a column for the word *elephant*.  perhaps Trump mentioned it in exactly one utterance referring to his son's hunting expedition. And a column for *xylophone*.  We might have 50,000 columns.
#
# The rows of our table are the individual email messages. So if an email contained 2 occurrences of *mess* that row will have a 2 in the mess column. But most email messages don't mention *Obama*, *compassion* or *mess*, much less mention rarer words like *elephant* or *xylophone* so the vast majority of cells in our table will be zero. So representing this data in a table is inefficient. With the sparse matrix representation we just list the cells that are not zero. So in the example above `(0, 69)) 2 ` represented a '2' in row 0 column 69.
#
# #### Instead of doing fit and transform as separate steps, we can do fit and transform in one step:

# %%
features = vectorizer.fit_transform(tinyCorpus)

# %% [markdown]
# Let's move on to other pre-processing steps we might need.
#
# ## Low information words
# For some applications, some words provide less information than others. For example,  the word *this* may be informative for some tasks. But for other tasks like deciding if the text is about pianos or motorcycles the word is considered uninformative. Other examples  of low-information words might be *the, a, this, that, on, of,*
#
# Some data scientists believe that these low-information, high-frequency words constitute noise and they remove them in a pre-processing step. These words we are removing are called **stop words**
#
# For example, if the stop words are *a, and, be, the, will* and we have the sentence
#
#          be a kind and compassionate person
#
# we will end up with
#
#               kind    compassionate  person
#
# ## Do this exactly once
# When you installed Anaconda you did not install the stopword lists. To do so (and **you only need to do this once**) execute the following:

# %%
# ONLY DO THIS ONCE
import nltk
nltk.download('all', halt_on_error=False)

# %% [markdown]
# Now that we downloaded the lists to our laptops let's take a look at the English stopwords.

# %%
from nltk.corpus import stopwords

# %%
swords = stopwords.words('english')

# %%
len(swords)
# Out:
# 179

# %%
print(swords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %% [markdown]
# We are going to use these stopwords shortly, but let's continue the tour of pre-processing steps.
#
# # stemming
#
# You may know that the structure of a sentence is called syntax. So  the sentence *The dogs chased the ball*  consists of a noun phrase (NP - *the dog*) followed by a verb phrase (VP - *chased the ball*) and the VP consists of a verb (*chased*) followed by an NP (*the ball*) and finally the NP consists of a determiner *the* followed by a noun *ball*.  And we get a syntactic structure that looks like:
#
#                                     S
#                                   /   \
#                                  /     \
#                                 /       \
#                                NP        VP
#                              /   \      |   \
#                             Det   N     V    \
#                             |     |     |      NP
#                            the   dogs  chased  |  \
#                                                |   \
#                                               Det   N
#                                                |    |
#                                               the  ball
#
# Similarly, words have internal structure. So *dogs* is really `dog+PLURAL` and *chased* is `chase+PAST`. This structure is called morphology and the analysis step is called morphological analysis. For many classification tasks, we don't care whether the person wrote *dogs* or *dog*. Or *chasing*, *chased*, or *chases* instead of *chase*. We might want to count all those variants of *chase* simply as *chase*. So instead of having separate attributes for *chase*, *chasing*, *chased*, and *chases*, we reduce it to 1.
#
# The absolute best way to do this task is with a morphological analyzer but it turns out that writing a good morphological analyzer is extremely tricky so data scientists use a much simpler solution called **stemming**. There are a number of stemming algorithms available to us. Here is how to use one called the Snowball Stemmer:

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer('english')
stemmer.stem('dogs')
# Out:
# 'dog'

# %%
print(stemmer.stem('chasing'))
print(stemmer.stem('chased'))
print(stemmer.stem('chases'))
# Out:
# chase
# chase
# chase

# %% [markdown]
# The above look like real words, but this is not always the case with a stemmer:

# %%
print(stemmer.stem('everyone'))
print(stemmer.stem('please'))
# Out:
# everyon
# pleas

# %% [markdown]
# ## QUIZ - sort of
#
# let's say we want to do all of
#
# * creating a bag of words
# * stem the words
# * remove stop words
#
# What order would we do this in?
#
# Would we create the bag of words and then stem? Or vice versa?
#
#
#
#
# # TF-IDF representation
#
# We could represent a document as a bag of words and their probabilities. For example, in *Tom Sawyer* 4.6% of the words are *the* and 0.95% are *Tom*. But *the* probably occurs in most novels with that frequency. So in some sense *the* is uninteresting. On the other hand *Tom* probably occurs much more frequently in *Tom Sawyer* than it does in *Moby Dick*. One way to discount words that occur evenly throughout our document collection is to use TF-IDF.
#
# * TF: Term Frequency - each word uprated by how often the word occurs in the document.
# * IDF Inverse Document Frequency - how often the word appears in the entire corpus
#
# and the formula is
#
# ### $$ tfidf(t, d) = tf(t,d) \times idf(t) $$
#
# where *t* is the term (the word) and *d* is the document.
#
# To explain this I will use some made up data--the word counts of 5 emails:
#
# id | the | sad | compassion |
# ---- | :---: | :---:
# 1 | 3 | 0 | 1
# 2 | 3 | 0 | 0
# 3 | 4 | 0 | 0
# 4 | 3 | 2 | 0
# 5 | 3 | 0 | 2
#
#
# The intuition is this. Even though the word *the* occurs frequently in each email, it is unlikely to help us classify email because it occurs in **every** email. The words *sad* and *compassion* are more interesting as they don't occur uniformly in our collection.
#
# The TF part of TF-IDF refers to how often the word occurs in the document. So for example, the TF of *the* in document 1 is 3. And IDF is defined as:
#
# ### $$ idf(t)=\log\frac{1+n_d}{1+df(d,t)}+ 1 $$
#
# $n_d$ is the total number of documents and $df(d,t)$ is how many documents the term *t* occurred in.
#
# So:
#
# ### $$ idf(the)=\log\frac{1+5}{1+5}+ 1 =  1.5 $$
#
# ### $$ idf(compassion)=\log\frac{1+5}{1+2}+ 1 = \log{2} + 1 =  2 $$
#
# So, *the* in document 1 has a tf-idf of $3 \times 1.5 = 4.5$ and *compassion* has a tf-idf of $1 \times \ 2 = 2$
#
# Here is how to do it in sklearn

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(stop_words='english')
features_train_transformed = vectorizer.fit_transform(tinyCorpus)
features_train = features_train_transformed.toarray()

# %% [markdown]
# # removing punctuation
# suppose I have the following important email:

# %%
important_email = """
To: Ron Zacharski <ron.zacharski@gmail.com>
From: Susan Williams <desmondwilliams614@yahoo.com>
Reply-To: Susan Williams <deswill0119@yahoo.fr>
Message-ID: <1860373470.1061917.1488479328300@mail.yahoo.com>
Subject: Hello,
MIME-Version: 1.0
Content-Type: text/plain; charset=UTF-8

Hello,

Greetings. With warm heart I offer my friendship and greetings, and I hope that this mail 
will meets you in good time.

However strange or surprising this contact might seem to you as we have not meet personally 
or had any dealings in the past. I humbly ask that you take due consideration of its 
importance and immense benefit.

My name is Susan Williams from Republic of Sierra-Leone. I have something very important 
that i would like to confide in you please,I have a reasonable amount of money which 
i inherited from my late father (Nine Million Five Hundred thousand United States Dollar}.
US$9.500.000.00.which I want to invest in your country with you and again in a very 
profitable venture.
"""

# %% [markdown]
# The first thing we could do is get the body of the email and strip out the header. We can do that as follows:

# %%
content = important_email.split("Content-Type: text/plain; charset=UTF-8")
print(content[1])
# Out:
# Hello,
#
# Greetings. With warm heart I offer my friendship and greetings, and I hope that this mail
# will meets you in good time.
#
# However strange or surprising this contact might seem to you as we have not meet personally
# or had any dealings in the past. I humbly ask that you take due consideration of its
# importance and immense benefit.
#
# My name is Susan Williams from Republic of Sierra-Leone. I have something very important
# that i would like to confide in you please,I have a reasonable amount of money which
# i inherited from my late father (Nine Million Five Hundred thousand United States Dollar}.
# US$9.500.000.00.which I want to invest in your country with you and again in a very
# profitable venture.

# %% [markdown]
# ## Mindfulness
# Okay, and here is my warning. So before you do some machine learning task, THINK. For example, don't blindly, automatically, delete stop words from a text -- think if that is required for your task. Similarly, before you strip out punctuation, decide on whether your task requires it. For example, maybe Spam detection would be improved by examining punctuation!!!! With that in mind, here is how you would remove punctuation.
#
# ### removing punctuation

# %%
import string
translator = str.maketrans('', '', string.punctuation)
text_string = content[1].translate(translator)
text_string
# Out:
# '\n\nHello\n\nGreetings With warm heart I offer my friendship and greetings and I hope that this mail \nwill meets you in good time\n\nHowever strange or surprising this contact might seem to you as we have not meet personally \nor had any dealings in the past I humbly ask that you take due consideration of its \nimportance and immense benefit\n\nMy name is Susan Williams from Republic of SierraLeone I have something very important \nthat i would like to confide in you pleaseI have a reasonable amount of money which \ni inherited from my late father Nine Million Five Hundred thousand United States Dollar\nUS950000000which I want to invest in your country with you and again in a very \nprofitable venture\n'

# %% [markdown]
# <h1 style="color:red">Partner Mini-Project</h1>
# This project is from the Udacity Course *Introduction to Machine Learning*
#
# We are going to work through, step-by-step, the pre-processing we must do to prepare a text for a classification task like Naive Bayes.
#
# #### Note
# In addition to the Enron Email corpus you will need three files:
#
# 1. [test_email.txt](https://raw.githubusercontent.com/zacharski/machine-learning/master/data/test_email.txt)
# 2. [from_sara.txt]( https://raw.githubusercontent.com/zacharski/machine-learning/master/data/from_sara.txt)
# 3. [from_chris.txt](https://raw.githubusercontent.com/zacharski/machine-learning/master/data/from_chris.txt)
#
#
# ## Part 1. Remove punctuation
# Below, the Udacity team gives us the function `parseOutText()`
#
# `parseOutText()` takes the opened email and returns only the text part, stripping away any metadata that may occur at the beginning of the email, so what's left is the text of the message.
#
# The first step we need to do is remove the punctuation from the text part of the email.  Please make that change.

# %%
def parseOutText(f):
    """ given an opened email file f, parse out all text below the
        metadata block at the top
        (in Part 2, you will also add stemming capabilities)
        and return a string that contains all the words
        in the email (space-separated) 
        
        example use case:
        f = open("email_file_name.txt", "r")
        text = parseOutText(f)
        
        """
    f.seek(0)  ### go back to beginning of file (annoying)
    all_text = f.read()
    ### split off metadata
    content = all_text.split("X-FileName:")
    words = ""
    if len(content) > 1:
        
        text_string = content[1]
        ### project part 1: remove punctuation
        
        
        
        ### project part 2: comment out the line below
        words = text_string
        

        ### split the text string into individual words, stem each word,
        ### and append the stemmed word to words (make sure there's a single
        ### space between each stemmed word)
        




    return words

def main():
    ff = open("../data/test_email.txt", "r")
    text = parseOutText(ff)
    print (text)



main()
# Out:
# Hi Everyone!  If you can read this message, you're properly using parseOutText.  Please proceed to the next part of the project!

# %% [markdown]
# You function should return
#
#     Hi Everyone  If you can read this message youre properly using parseOutText  Please proceed to the next part of the project
#
# ## Part 2. Stemming
#
# In `parseOutText()`, comment out the following line:
#
# `words = text_string`
#
# Augment `parseOutText()` so that the string it returns has all the words stemmed using a SnowballStemmer (use the nltk package, some examples that I found helpful can be found here: [http://www.nltk.org/howto/stem.html](http://www.nltk.org/howto/stem.html) ). Rerun parse_out_email_text.py, which will use your updated parseOutText() function--what’s your output now?
#
# Hint: you'll need to break the string down into individual words, stem each word, then recombine all the words into one string.  Suppose I have a list of words:

# %%
lacksZs = ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
lacksZs
# Out:
# ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# %% [markdown]
# and suppose I have a function `addZ` that appends a `z` to a word. I can apply that function to each element of a list and create a string result as follows:

# %%
def addZ(word):
    return word + 'z'

tmp = map(addZ, lacksZs)
result = ' '.join(tmp)
result
# Out:
# 'thez quickz brownz foxz jumpsz overz thez lazyz dogz'

# %% [markdown]
# that hint should help a bit when adding the stemming code.
# Either edit your code above. Or copy and paste it below and make the edit here:

# %%
def parseOutText(f):
    """ given an opened email file f, parse out all text below the
        metadata block at the top
        (in Part 2, you will also add stemming capabilities)
        and return a string that contains all the words
        in the email (space-separated) 
        
        example use case:
        f = open("email_file_name.txt", "r")
        text = parseOutText(f)
        
        """
    f.seek(0)  ### go back to beginning of file (annoying)
    all_text = f.read()
    ### split off metadata
    content = all_text.split("X-FileName:")
    words = ""
    if len(content) > 1:
        
        text_string = content[1]
        ### project part 1: remove punctuation
        
        
        
        ### project part 2: comment out the line below
        words = text_string
        

        ### split the text string into individual words, stem each word,
        ### and append the stemmed word to words (make sure there's a single
        ### space between each stemmed word)
        




    return words

def main():
    ff = open("../data/test_email.txt", "r")
    text = parseOutText(ff)
    print (text)



main()
# Out:
# hi everyon if you can read this messag your proper use parseouttext pleas proceed to the next part of the project

# %% [markdown]
# your function should return:
#
#     hi everyon if you can read this messag your proper use parseouttext pleas proceed to the next part of the project
#
# ## Part 3 - Downloading 400MB of the Enron Email Dataset
# You only need to do this once (so using the 'Run All Cells' command on this notebook might not be a wise decision.
#
# Prior to the Hillary Clinton email dataset, the Enron dataset was the largest publically available email set in the known universe. According to Wikipedia: "The Enron Corpus is a large database of over 600,000 emails generated by 158 employees[1] of the Enron Corporation and acquired by the Federal Energy Regulatory Commission during its investigation after the company's collapse."
#
# Our goal for this mini-project is to use emails from two people to see if we can build a classifier that can identify the author of an email.
#
# Because of its size and the resulting length of time it will take, let's divide the code into 2 cells:
#
# #### first download ...
#
# Feel free to change the location of the download.

# %%
import urllib
url = "https://www.cs.cmu.edu/~./enron/enron_mail_20150507.tar.gz"
urllib.request.urlretrieve(url, filename="../enron_mail_20150507.tar.gz") 
print ("download complete!")
# Out:
# download complete!

# %% [markdown]
# #### now uncompress it!

# %%
import tarfile
import os
os.chdir("..")
tfile = tarfile.open("enron_mail_20150507.tgz", "r:gz")
tfile.extractall(".")
os.chdir("notebooks")
print ("you're ready to go!")
# Out:
# you're ready to go!

# %% [markdown]
# ## Part 4 - read the data and stem it
# Just to reiterate, this mini-project and the majority of the write-up is from Udacity. They did a great job in putting this together.
#
# In the next code block, you will iterate through all the emails from Chris and from Sara. For each email, feed the opened email to parseOutText() and return the stemmed text string. Then do two things:
#
# 1. apply parseOutText to extract the text from the opened email
# 2. remove signature words (“sara”, “shackleton”, “chris”, “germani”--bonus points if you can figure out why it's "germani" and not "germany")
# 2. append the updated text string to word_data -- if the email is from Sara, append 0 (zero) to from_data, or append a 1 if Chris wrote the email.
#
# Once this step is complete, you should have two lists: one contains the stemmed text of each email, and the second should contain the labels that encode (via a 0 or 1) who the author of that email is.
#
# Running over all the emails can take a little while (5 minutes or more), so we've added a temp_counter to cut things off after the first 200 emails. Of course, once everything is working, you'd want to run over the full dataset.

# %%
# CODE FROM UDACITY

import os
import pickle
import re
import sys
import string # raz



"""
    Starter code to process the emails from Sara and Chris to extract
    the features and get the documents ready for classification.

    The list of all the emails from Sara are in the from_sara list
    likewise for emails from Chris (from_chris)

    The actual documents are in the Enron email dataset, which
    you downloaded/unpacked in Part 0 of the first mini-project. If you have
    not obtained the Enron email corpus, run startup.py in the tools folder.

    The data is stored in lists and packed away in pickle files at the end.
"""



from_sara  = open("../data/from_sara.txt", "r")
from_chris = open("../data/from_chris.txt", "r")

from_data = []
word_data = []

### temp_counter is a way to speed up the development--there are
### thousands of emails from Sara and Chris, so running over all of them
### can take a long time
### temp_counter helps you only look at the first 200 emails in the list so you
### can iterate your modifications quicker
temp_counter = 0


for name, from_person in [("sara", from_sara), ("chris", from_chris)]:
    print('PROCESSING  ' + name)
    temp_counter = 0
    for path in from_person:
        ### only look at first 200 emails when developing
        ### once everything is working, remove this line to run over full dataset
        temp_counter += 1
        if temp_counter < 200 or 1 == 1:   # raz
            path = os.path.join('/Users/raz/Documents/machineLearning/', path[:-1])
            #print(path)
            email = open(path, "r")
            

            ### use parseOutText to extract the text from the opened email

            
            ### use str.replace() to remove any instances of the words
            ### ["sara", "shackleton", "chris", "germani"]

            ### append the text to word_data
            
            ### append a 0 to from_data if email is from Sara, and 1 if email is from Chris

            email.close()    

print ("emails processed")
from_sara.close()
from_chris.close()
    
# uncomment this out when you have the above working. 
#with open('../data/word_data.pkl', 'wb') as word_file:
#    pickle.dump( word_data, word_file)
#with open('../data/email_authors.pkl', 'wb') as author_file:
#    pickle.dump( from_data, author_file)

print('Processing Complete')
# Out:
# PROCESSING  sara
# PROCESSING  chris
# emails processed
#   0:  sbaile2 nonprivilegedpst susan pleas sen
#   0:  sbaile2 nonprivilegedpst 1 txu energi tr
#   0:  sbaile2 nonprivilegedpst all here the se
#   0:  sbaile2 nonprivilegedpst   enron wholesa
#   0:  sbaile2 nonprivilegedpst origin messag f
#   0:  sbaile2 nonprivilegedpst we need to rese
#   0:  sbaile2 nonprivilegedpst we cannot locat
#   0:  sbaile2 nonprivilegedpst origin messag f
#   0:  sbaile2 nonprivilegedpst did domin carol
#   0:  sbaile2 nonprivilegedpst weezi pleas ema
#   0:  sbaile2 nonprivilegedpst i alreadi spoke
#   0:  sbaile2 nonprivilegedpst baltimor gas el
#   0:  sbaile2 nonprivilegedpst someon from set
#   0:  sbaile2 nonprivilegedpst fyi origin mess
#   0:  sbaile2 nonprivilegedpst debbi is send c
#   0:  sbaile2 nonprivilegedpst 1 citizen gas u
#   0:  sbaile2 nonprivilegedpst susan pleas add
#   0:  sbaile2 nonprivilegedpst receiv written
#   0:  sbaile2 nonprivilegedpst 1 receiv a voic
#   0:  sbaile2 nonprivilegedpst myra gari 87072
#   0:  sbaile2 nonprivilegedpst i receiv a voic
#   0:  sbaile2 nonprivilegedpst origin messag f
#   0:  sbaile2 nonprivilegedpst jim are you loo
#   0:  sbaile2 nonprivilegedpst loui just a rem
#   0:  sbaile2 nonprivilegedpst spoke with dale
#   0:  sbaile2 nonprivilegedpst even though we
#   0:  sbaile2 nonprivilegedpst you should show
#   0:  sbaile2 nonprivilegedpst i receiv a vali
#   0:  sbaile2 nonprivilegedpst we need to prep
#   0:  sbaile2 nonprivilegedpst susan can you a
#   0:  sbaile2 nonprivilegedpst bob can you ple
#   0:  mheard nonprivilegedpst mari ok here a r
#   0:  mheard nonprivilegedpst sheila pleas sen
#   0:  mheard nonprivilegedpst sheila pleas sen
#   0:  mheard nonprivilegedpst let add this to
#   0:  mheard nonprivilegedpst daniel with resp
#   0:  mheard nonprivilegedpst pleas forward yo
#   0:  mheard nonprivilegedpst tom there is no
#   0:  mheard nonprivilegedpst thresa just fyi
#   0:  mheard nonprivilegedpst pleas forward yo
#   0:  mheard nonprivilegedpst pleas forward yo
#   0:  mheard nonprivilegedpst origin messag fr
#   0:  mheard nonprivilegedpst ill touch base w
#   0:  mheard nonprivilegedpst pleas print and
#   0:  mheard nonprivilegedpst sheila thank mar
#   0:  mheard nonprivilegedpst fyi origin messa
#   0:  mheard nonprivilegedpst i have an 830 am
#   0:  mheard nonprivilegedpst origin messag fr
#   0:  mheard nonprivilegedpst daniel what abou
#   0:  mheard nonprivilegedpst origin messag fr
#   0:  mheard nonprivilegedpst daniel the term
#   0:  mheard nonprivilegedpst gil pleas includ
#   0:  mheard nonprivilegedpst our friend is ca
#   0:  mheard nonprivilegedpst tom we would lik
#   0:  mheard nonprivilegedpst traci let me kno
#   0:  mheard nonprivilegedpst fyi am speak wit
#   0:  mheard nonprivilegedpst jeanpierr we are
#   0:  mheard nonprivilegedpst origin messag fr
#   0:  mheard nonprivilegedpst origin messag fr
#   0:  mheard nonprivilegedpst origin messag fr
#   0:  mheard nonprivilegedpst sheila mari is l
#   0:  mheard nonprivilegedpst i thought you mi
#   0:  mheard nonprivilegedpst mari here what j
#   0:  mheard nonprivilegedpst spoke with ed sa
#   0:  mheard nonprivilegedpst h per my voic ma
#   0:  mheard nonprivilegedpst tom i just recei
#   0:  mheard nonprivilegedpst tanya we have pr
#   0:  mheard nonprivilegedpst here it is im fa
#   0:  sshacklensf   enron north america corp 1
#   0:  sshacklensf gail attach is a form of eci
#   0:  sshacklensf carol 1 see tanya note re oc
#   0:  sshacklensf ldngc seri 1998 a trust   en
#   0:  sshacklensf with respect to part 2 tax r
#   0:  sshacklensf tom i forward a copi of the
#   0:  sshacklensf carol i cant recal if we dis
#   0:  sshacklensf how can i get in touch with
#   0:  sshacklensf gail the commerci team is pr
#   0:  sshacklensf the prior trade disput resul
#   0:  sshacklensf forward by  houect on 122199
#   0:  sshacklensf jim and rex the lehman bros
#   0:  sshacklensf hey you and i think alik be
#   0:  sshacklensf attach is a draft doc i didn
#   0:  sshacklensf the draft is readi to go but
#   0:  sshacklensf forward by  houect on 122199
#   0:  sshacklensf did you speak with your ectr
#   0:  sshacklensf michael attach is a revis bl
#   0:  sshacklensf attach is the latest draft o
#   0:  sshacklensf dick i am suggest a minor ch
#   0:  sshacklensf janell im not sure if this i
#   0:  sshacklensf cant recal if i ask you to r
#   0:  sshacklensf tanya bob crane did a deal w
#   0:  sshacklensf mari can you assign susan to
#   0:  sshacklensf forward by  houect on 122199
#   0:  sshacklensf yair are we finish pleas let
#   0:  sshacklensf hi matthew sorri for the lat
#   0:  sshacklensf frank pleas refresh my geria
#   0:  sshacklensf traci can you call me and le
#   0:  sshacklensf all i receiv a draft master
#   0:  sshacklensf traci further to my earlier
#   0:  sshacklensf tanya for purpos of transfer
#   0:  sshacklensf 1 the enron compani is ena 2
#   0:  sshacklensf yes im avail what time work
#   0:  sshacklensf tom thank for the info i did
#   0:  sshacklensf see ya in el lobbyo at noon
#   0:  sshacklensf mara 1 the second setoff par
#   0:  sshacklensf thank we amend the guaranti
#   0:  sshacklensf just to be certain that the
#   0:  sshacklensf stephani the attach messag i
#   0:  sshacklensf carson im on the phone with
#   0:  sshacklensf carolin pleas give me a call
#   0:  sshacklensf april 17   enron north ameri
#   0:  sshacklensf paul were you go to send me
#   0:  sshacklensf fyi forward by  houect on 12
#   0:  sshacklensf carol regard a hedg fund mee
#   0:  sshacklensf gail is the attach master re
#   0:  sshacklensf matthew in conjunct with our
#   0:  sshacklensf thank ani word on the consen
#   0:  sshacklensf gsco and gsi have differ rep
#   0:  sshacklensf forward by  houect on 122299
#   0:  sshacklensf kay pleas reschedul the meet
#   0:  sshacklensf anna i would like to fax the
#   0:  sshacklensf attach is a sampl option ple
#   0:  sshacklensf jay and wendi i havent heard
#   0:  sshacklensf tanya our fxcurrenc trader i
#   0:  sshacklensf i have been unabl to reach a
#   0:  sshacklensf hi kristina it was great spe
#   0:  sshacklensf kay without make this too co
#   0:  sshacklensf carolin fred want to meet in
#   0:  sshacklensf we will keep the 10 am meet
#   0:  sshacklensf automat termin provis if the
#   0:  sshacklensf fred cannot meet at 10 am tu
#   0:  sshacklensf just spoke with mark russel
#   0:  sshacklensf kim mark russel ask what law
#   0:  sshacklensf 1 were keep the tuesday 10 a
#   0:  sshacklensf forward by  houect on 122299
#   0:  sshacklensf is there ani intent of sell
#   0:  sshacklensf carolin i am in the midst of
#   0:  sshacklensf paul with respect to valenti
#   0:  sshacklensf paul further to my earlier e
#   0:  sshacklensf i did speak with ana soria h
#   0:  sshacklensf pleas add to your calendar
#   0:  sshacklensf aneela i receiv the referenc
#   0:  sshacklensf   enron north america corp 1
#   0:  sshacklensf   enron north america corp 1
#   0:  sshacklensf we need to call these guy
#   0:  sshacklensf here it is i didnt prepar th
#   0:  sshacklensf i dont   enron north america
#   0:  sshacklensf anna could i pleas have your
#   0:  sshacklensf kristina i thought her email
#   0:  sshacklensf michael i didnt receiv a red
#   0:  sshacklensf melissa we agre to the form
#   0:  sshacklensf melissa a spark spread is ba
#   0:  sshacklensf kim when you have a minut pl
#   0:  sshacklensf  we should chat per the isda
#   0:  sshacklensf stephani let me know what yo
#   0:  sshacklensf fyi   enron north america co
#   0:  sshacklensf becki pleas send email to mp
#   0:  sshacklensf i order a 75 flower arrang f
#   0:  sshacklensf per my voic mail we should p
#   0:  sshacklensf forward by  houect on 010420
#   0:  sshacklensf fyi   enron north america co
#   0:  sshacklensf i cant rememb exact mayb 400
#   0:  sshacklensf melissa i just got this but
#   0:  sshacklensf pend execut of a master agre
#   0:  sshacklensf laurel i have left messag wi
#   0:  sshacklensf yair traci and i would like
#   0:  sshacklensf i should be in immedi after
#   0:  sshacklensf carolin no deem isda we deci
#   0:  sshacklensf attach is the most recent dr
#   0:  sshacklensf traci it fine with me let sc
#   0:  sshacklensf carolin as you know carol is
#   0:  sshacklensf how about 11 am cst i forgot
#   0:  sshacklensf just receiv this messag this
#   0:  sshacklensf happi new year and did we ev
#   0:  sshacklensf yair i am unavail wed fri ne
#   0:  sshacklensf susan we need to prepar mate
#   0:  sshacklensf thank for your help i also l
#   0:  sshacklensf   enron north america corp 1
#   0:  sshacklensf susan laurel adam has an fx
#   0:  sshacklensf mark we should rotat the des
#   0:  sshacklensf   enron north america corp 1
#   0:  sshacklensf in case no one told you bren
#   0:  sshacklensf pleas dont email to the part
#   0:  sshacklensf will monday or tuesday after
#   0:  sshacklensf   enron north america corp 1
#   0:  sshacklensf paul there is alreadi a defi
#   0:  sshacklensf   enron north america corp 1
#   0:  sshacklensf   enron north america corp 1
#   0:  sshacklensf is maud perrodin with banqu
#   0:  sshacklensf ani comment   enron north am
#   0:  sshacklensf here the origin blacklin lea
#   0:  sshacklensf marycheryl carol has seven 7
#   0:  sshacklensf sheila pleas send the futur
#   0:  sshacklensf melissa merchant look good p
#   0:  sshacklensf carol below is the list of i
#   0:  sshacklensf see the doc below for make r
#   0:  sshacklensf kay ill give you my comment
#   0:  sshacklensf carolin you should have alre
#   0:  sshacklensf carolin your email is the fi
#   0:  sshacklensf forward by  houect on 010520
#   0:  sshacklensf sorri carolin   enron north
#   0:  sshacklensf attach is the form of guaran
#   0:  sshacklensf mark can you publish a list
#   0:  sshacklensf brent it a weather question
#   0:  sshacklensf celest ive ask brent to give
#   0:  sshacklensf yair pleas let us know if we
#   0:  sshacklensf melissa i start with sempra
#   0:  sshacklensf happi new year attach is a n
#   0:  sshacklensf deseret omnibus empresa than
#   0:  sshacklensf edmund would you believ that
#   0:  sshacklensf marcelo when we last spoke o
#   0:  sshacklensf   enron north america corp 1
#   0:  sshacklensf here the attach termsheet fo
#   0:  sshacklensf a few item to clarifi 1 doe
#   0:  sshacklensf hey i felt like i was in la
#   0:  sshacklensf mae charl attach is the form
#   0:  sshacklensf yair pleas give me a call we
#   0:  sshacklensf fyi enron south america has
#   0:  sshacklensf second messag from bruce for
#   0:  sshacklensf cheryl thank also pleas note
#   0:  sshacklensf mark pleas let talk when you
#   0:  sshacklensf mark we need to discuss than
#   0:  sshacklensf attach are draft for 1 short
#   0:  sshacklensf fyi   enron north america co
#   0:  sshacklensf fyi   enron north america co
#   0:  sshacklensf   enron north america corp 1
#   0:  sshacklensf frank did i hear you mention
#   0:  sshacklensf andrew thank for the email i
#   0:  sshacklensf im still review the isda but
#   0:  sshacklensf marcelo thank for the respon
#   0:  sshacklensf frank do you want to handl t
#   0:  sshacklensf nikki i am a lawyer with ena
#   0:  sshacklensf pamela i am also send you th
#   0:  sshacklensf paul i need to speak with yo
#   0:  sshacklensf just to be on the safe side
#   0:  sshacklensf fyi onli   enron north ameri
#   0:  sshacklensf nanci i left a voic mail for
#   0:  sshacklensf tanya our fx desk has reques
#   0:  sshacklensf david pleas send an email re
#   0:  sshacklensf the second email forward by
#   0:  sshacklensf terri and dee i am resend th
#   0:  sshacklensf marcelo we are readi to exec
#   0:  sshacklensf no same date are fine with m
#   0:  sshacklensf fyi forward by  houect on 01
#   0:  sshacklensf   enron north america corp 1
#   0:  sshacklensf thank so much for your quick
#   0:  sshacklensf   enron north america corp 1
#   0:  sshacklensf susan should have alreadi ch
#   0:  sshacklensf forward by  houect on 011320
#   0:  sshacklensf   enron north america corp 1
#   0:  sshacklensf mari is not in the offic tod
#   0:  sshacklensf   enron north america corp 1
#   0:  sshacklensf   enron north america corp 1
#   0:  sshacklensf mari i didnt know you were a
#   0:  sshacklensf urgent trader tri to trade w
#   0:  sshacklensf thank for the tax articl it
#   0:  sshacklensf   enron north america corp 1
#   0:  sshacklensf cheryl attach are welch comm
#   0:  sshacklensf mike i sent a request for a
#   0:  sshacklensf pleas assign it rmt and were
#   0:  sshacklensf pamela pleas call or email r
#   0:  sshacklensf donna see the attach for lat
#   0:  sshacklensf donna see if this work if it
#   0:  sshacklensf dian let add these provis an
#   0:  sshacklensf i just want to touch base wi
#   0:  sshacklensf   enron north america corp 1
#   0:  sshacklensf   enron north america corp 1
#   0:  sshacklensf   enron north america corp 1
#   0:  sshacklensf forward by  houect on 011420
#   0:  sshacklensf  regard tanya comment no 3 b
#   0:  sshacklensf dian thank pleas dont send u
#   0:  sshacklensf tim fyi mari cook ask that i
#   0:  sshacklensf mari teresa here the latest
#   0:  sshacklensf lisa fyi there has been acti
#   0:  sshacklensf im not sure who is handl tan
#   0:  sshacklensf should we invit one of the t
#   0:  sshacklensf mari shemeika landri x52552
#   0:  sshacklensf susan pleas assign someon to
#   0:  sshacklensf marshal attach are the draft
#   0:  sshacklensf   enron north america corp 1
#   0:  sshacklensf dont you dare leav without s
#   0:  sshacklensf dian attach is my redlin mos
#   0:  sshacklensf karolina pleas call me in th
#   0:  sshacklensf frank i know you just receiv
#   0:  sshacklensf derek im on the phone is thi
#   0:  sshacklensf what meet   enron north amer
#   0:  sshacklensf per my voic mail pleas respo
#   0:  sshacklensf   enron north america corp 1
#   0:  sshacklensf derek gail shanley goldman s
#   0:  sshacklensf gail my london trader derek
#   0:  sshacklensf sorri for the extrem delay i
#   0:  sshacklensf i am tri to distinguish thes
#   0:  sshacklensf dian attach is the redlin re
#   0:  sshacklensf cheryl attach are con ed doc
#   0:  sshacklensf jorg i havent forgotten you
#   0:  sshacklensf i have review tana list of n
#   0:  sshacklensf pushkar do you have the emai
#   0:  sshacklensf just spoke with  you should
#   0:  sshacklensf sheila here the status 1 gol
#   0:  sshacklensf would someon pleas provid me
#   0:  sshacklensf cheryl im forward welch requ
#   0:  sshacklensf were wait for teresa bushman
#   0:  sshacklensf the financi trade group has
#   0:  sshacklensf did susan call you new rmt m
#   0:  sshacklensf gennaro nanci callahan and i
#   0:  sshacklensf pleas see attach thank  forw
#   0:  sshacklensf   enron north america corp 1
#   0:  sshacklensf tanya i fax the prior credit
#   0:  sshacklensf here it is   enron north ame
#   0:  sshacklensf tanya pleas see page 7 of th
#   0:  sshacklensf i hope bruce explan is suffi
#   0:  sshacklensf sheila ena is readi to sign
#   0:  sshacklensf tana the follow peopl have r
#   0:  sshacklensf what the purpos of this   en
#   0:  sshacklensf i dont know if you have spok
#   0:  sshacklensf limor i hope this help regar
#   0:  sshacklensf   enron north america corp 1
#   0:  sshacklensf fyi forward by  houect on 01
#   0:  sshacklensf mari attach is the latest dr
#   0:  sshacklensf   enron north america corp 1
#   0:  sshacklensf can you email a copi of the
#   0:  sshacklensf sheila pleas call me when yo
#   0:  sshacklensf mari thank for the email no
#   0:  sshacklensf damon attach is the document
#   0:  sshacklensf damon attach is the other do
#   0:  sshacklensf sheila attach is the compare
#   0:  sshacklensf brent attach is aparna email
#   0:  sshacklensf tri to set up confer call wi
#   0:  sshacklensf i am follow up with ms but i
#   0:  sshacklensf damon can you print the agre
#   0:  sshacklensf tanya if you check lotus not
#   0:  sshacklensf   enron north america corp 1
#   0:  sshacklensf cathi attach is mari email w
#   0:  sshacklensf here my origin email   enron
#   0:  sshacklensf all attach below is the repo
#   0:  sshacklensf hi tian stuart has alreadi c
#   0:  sshacklensf fyi from earlier today   enr
#   0:  sshacklensf mari sharon chernick email a
#   0:  sshacklensf   enron north america corp 1
#   0:  sshacklensf doe mark have time in the af
#   0:  sshacklensf susan check the pge isda sch
#   0:  sshacklensf id like to meet thursday jun
#   0:  sshacklensf susan i just spoke with csfb
#   0:  sshacklensf tian pleas mark this time on
#   0:  sshacklensf these are fine as long as th
#   0:  sshacklensf stewart fyi ill probabl have
#   0:  sshacklensf fyi onli tanya lot of new ac
#   0:  sshacklensf holli pleas see tian messag
#   0:  sshacklensf mari ok here a request from
#   0:  sshacklensf mark attach is my current wo
#   0:  sshacklensf markrod ill draft the annex
#   0:  sshacklensf david attach are the string
#   0:  sshacklensf tian how is 3 pm houston1 pm
#   0:  sshacklensf are the certif to be issu by
#   0:  sshacklensf let schedul this pleas   enr
#   0:  sshacklensf tian 1 pm portland time on f
#   0:  sshacklensf jorg i never heard back from
#   0:  sshacklensf youll need this draft for la
#   0:  sshacklensf ill touch base with you this
#   0:  sshacklensf let add this to this afterno
#   0:  sshacklensf eci the morgan guaranti   en
#   0:  sshacklensf andi the follow name come to
#   0:  sshacklensf   enron north america corp 1
#   0:  sshacklensf   enron north america corp 1
#   0:  sshacklensf   enron north america corp 1
#   0:  sshacklensf morgan stanley has advis me
#   0:  sshacklensf stephani pleas email to vale
#   0:  sshacklensf sheila your prior email desc
#   0:  sshacklensf im alway in town just let me
#   0:  sshacklensf could someon pleas follow up
#   0:  sshacklensf   enron north america corp 1
#   0:  sshacklensf i would like to take the fol
#   0:  sshacklensf joe per jay voic mail to you
#   0:  sshacklensf ill need the file susan flyn
#   0:  sshacklensf   enron north america corp 1
#   0:  sshacklensf   enron north america corp 1
#   0:  sshacklensf gosh i had total forgotten t
#   0:  sshacklensf mcisda is sprout golden arch
#   0:  sshacklensf the adr certif can be direct
#   0:  sshacklensf i have been receiv the enron
#   0:  sshacklensf we are current updat our dat
#   0:  sshacklensf ena can confirm the transact
#   0:  sshacklensf as we just discuss ss forwar
#   0:  sshacklensf pleas respond thank ss forwa
#   0:  sshacklensf mark have you spoken with br
#   0:  sshacklensf have you and mark ever discu
#   0:  sshacklensf fyi forward by  houect on 01
#   0:  sshacklensf forward by  houect on 012420
#   0:  sshacklensf i will have the letter execu
#   0:  sshacklensf can we schedul a confer call
#   0:  sshacklensf i have two 2 ticket for wit
#   0:  sshacklensf let enter into the databas i
#   0:  sshacklensf attach is a redlin base upon
#   0:  sshacklensf happi new year i was hope yo
#   0:  sshacklensf let verifi that this is an i
#   0:  sshacklensf happi new year just wonder i
#   0:  sshacklensf i would like to pursu with m
#   0:  sshacklensf the lawyer of cours ss to  h
#   0:  sshacklensf joe hunter no longer handl f
#   0:  sshacklensf brent gabbi aguilar from ba
#   0:  sshacklensf i still need to revis the ag
#   0:  sshacklensf here my goof give me a call
#   0:  sshacklensf lynn will come to my offic a
#   0:  sshacklensf sorri to keep send email but
#   0:  sshacklensf let me know if you have comm
#   0:  sshacklensf am i nut forward by  houect
#   0:  sshacklensf i spoke briefli with gari pe
#   0:  sshacklensf im avail as well  forward by
#   0:  sshacklensf of cours just let me know wh
#   0:  sshacklensf i am final the doc and we sh
#   0:  sshacklensf super congratul ss enron cap
#   0:  sshacklensf i am current review jeff h w
#   0:  sshacklensf this is the latest paper dee
#   0:  sshacklensf i am still wait for my brazi
#   0:  sshacklensf you are fantast it look like
#   0:  sshacklensf no we insist that the trader
#   0:  sshacklensf that will be fine  to  houec
#   0:  sshacklensf pleas let me know if you nev
#   0:  sshacklensf pleas let me know what you t
#   0:  sshacklensf i just receiv a messag from
#   0:  sshacklensf attach is the origin list fr
#   0:  sshacklensf holli krebb just did a deal
#   0:  sshacklensf susan the doc are in my in b
#   0:  sshacklensf susan base on tanya messag w
#   0:  sshacklensf mark in connect with susan f
#   0:  sshacklensf here the email and thank for
#   0:  sshacklensf central puerto has been unre
#   0:  sshacklensf pleas print the xcel documen
#   0:  sshacklensf i will be on vacat from octo
#   0:  sshacklensf all i will be on vacat until
#   0:  sshacklensf welcom back pleas disabl you
#   0:  sshacklensf we will need to updat this i
#   0:  sshacklensf fyi brent pleas call sound l
#   0:  sshacklensf ill send you a fedex tonight
#   0:  sshacklensf could this be an altern to o
#   0:  sshacklensf thank ss kay elli 01312000 1
#   0:  sshacklensf attach is a short letter adv
# ...
#   1:    62502pst pete im follow up the voicema
#   1:    62502pst i just got to work about 10 m
#   1:    62502pst richard jame taylor was born
#   1:    62502pst pleas use bank account number
#   1:    62502pst i am a proud papa tire but pr
#   1:    62502pst reliant has agre to sell us g
#   1:    62502pst same as befor we should have
#   1:    62502pst schedul contact origin messag
#   1:    62502pst updat on a new swing supplier
#   1:    62502pst who do i talk to over there a
#   1:    62502pst margaret ive attach the prepa
#   1:    62502pst im busi that day just kid ori
#   1:    62502pst ok i see russel and chuck tou
#   1:    62502pst hey what about my pager
#   1:    62502pst i dont see you in msn messeng
#   1:    62502pst work for me thank origin mess
#   1:    62502pst actual i am the littl woman a
#   1:    62502pst jare is here ill tell him to
#   1:    62502pst 2 week ago i receiv a page an
#   1:    62502pst ditto see that mean im like p
#   1:    62502pst im leav for the day all of my
#   1:    62502pst so it was 1000 am and im abou
#   1:    62502pst im look for a general doctor
#   1:    62502pst terri kain with keyspan energ
#   1:    62502pst i dont see you on msn
#   1:    62502pst hey i just saw your email im
#   1:    62502pst hey not too much time to talk
#   1:    62502pst hey buddi you gave us the inf
#   1:    62502pst i have 2 email address german
#   1:    62502pst here is a littl more info in
#   1:    62502pst hi paul i just left you a voi
#   1:    62502pst hey buddi i just off my resum
#   1:    62502pst hi larri my name is   and i w
#   1:    62502pst thank origin messag from camp
#   1:    62502pst i tri to call you to hassel y
#   1:    62502pst here is anoth contract i need
#   1:    62502pst origin messag from   sent wed
#   1:    62502pst i have 2 more contract im loo
#   1:    62502pst to regist your palm comput or
#   1:    62502pst task assign task prioriti 1 t
#   1:  cgermannsf we park gas deal 240072 on th
#   1:  cgermannsf we park 25000 dtday on the 25
#   1:  cgermannsf per paulett hauer at calpgelp
#   1:  cgermannsf i creat deal 159513 to captur
#   1:  cgermannsf i need a new pipelin set up c
#   1:  cgerman nonprivilegedpst just so we all
#   1:  cgermannsf dan and i spoke with jim ecke
#   1:  cgermannsf i have fuel waiver on my cng
#   1:  cgermannsf just had a thought accord to
#   1:  cgermannsf forward by  germanyhouect on
#   1:  copi of shendrinsf we sold the nation fu
#   1:  copi of shendrinsf subject cute stori an
#   1:  copi of shendrinsf from the birmingham s
#   1:  copi of shendrinsf forward by  germanyho
#   1:  hendrickson scottpst pleas set up and an
#   1:  hendrickson scottpst origin messag from
#   1:  hendrickson scottpst we sold the nation
#   1:  hendrickson scottpst forward by  germany
#   1:  hodg johnpst origin messag from smith ma
#   1:  hodg johnpst per vngs request ena releas
#   1:  jhodge2 nonprivilegedpst calp releas the
#   1:  jhodge2 nonprivilegedpst tp1 sold 2000 d
#   1:  jhodge2 nonprivilegedpst these are the m
#   1:  jhodge2 nonprivilegedpst when i look at
#   1:  jhodg nonprivilegedpst terri kain with k
#   1:  jhodge2 nonprivilegedpst we have a disco
#   1:  jhodge2 nonprivilegedpst we are buy the
#   1:  jhodge2 nonprivilegedpst i borrow 19903
#   1:  jhodge2 nonprivilegedpst the tco book is
#   1:  jhodge2 nonprivilegedpst steve i forgot
#   1:  hodg johnpst pleas send copi of the vng
#   1:  hodg johnpst littl correct go forward th
#   1:  hodg johnpst current we are unabl to use
#   1:  dhyvlnsf pleas add dan to the list thank
#   1:  dhyvlnsf i spoke with traci geaccon afte
#   1:  pkeavey nonprivilegedpst djunekaeglobalm
#   1:  kam keiser 71102pst the boston different
#   1:  jmckay1 nonprivilegedpst tenn transport
#   1:  jmckay1 nonprivilegedpst boston gas diff
#   1:  jon mckay 71102pst 1162
#   1:  jon mckay 71102pst the boston differenti
#   1:  snealnsf pleas give judi townsend scott
#   1:  snealnsf pleas give my eol id the abil t
#   1:  scott neal 62602pst just so you dont for
#   1:  snealnsf pleas give judi townsend scott
#   1:  snealnsf pleas give my eol id the abil t
#   1:  neal scottpst pleas give me view onli ac
#   1:  sneal nonprivilegedpst boston gas differ
#   1:  sneal nonprivilegedpst juli im leav at 1
#   1:  neal scottpst pleas give my eol id the a
#   1:  neal scottpst pleas give judi townsend s
#   1:  joe park 62602pst but im go to tri and k
#   1:  joe park 62602pst hey i normal talk bad
#   1:  joe park 62602pst today i revis the 7000
#   1:  joe park 62602pst i purchas the 10000 dt
#   1:  joe park 62602pst i want to cancel the w
#   1:  joe park 62602pst i have request the fol
#   1:  joe park 62602pst i am request the follo
#   1:  joe park 62602pst the tallahasse deal st
#   1:  joe park 62602pst the contract number as
#   1:  joe park 62602pst dominion oklahoma texa
#   1:  joe park 62602pst per david walker at do
#   1:  joe park 62602pst this is what i heard p
#   1:  joe park 62602pst prepay and gas flow ac
#   1:  joe park 62602pst prepay for dominion fo
#   1:  joe park 62602pst the cia had an open fo
#   1:  joe park 62602pst titl midcontin gas tra
#   1:  joe park 62602pst i have an event that i
#   1:  joe park 62602pst sure i have one gas pu
#   1:  joe park 62602pst i never know what cont
#   1:  joe park 62602pst recommend for ena pool
#   1:  joe park 62602pst still not sure about t
#   1:  joe park 62602pst mark i assum you are t
#   1:  joe park 62602pst 31402 950 am per tammi
#   1:  joe park 62602pst job titl commerci mana
#   1:  joe park 62602pst ruth concannon told me
#   1:  joe park 62602pst sempra need to get a c
#   1:  joe park 62602pst these day it easier fo
#   1:  joe park 62602pst ed this gas was nomin
#   1:  joe park 62602pst there are 2 con ed and
#   1:  joe park 62602pst i believ cms market se
#   1:  joe park 62602pst 3602 230 pm just spoke
#   1:  joe park 62602pst summari tdc energi cor
#   1:  joe park 62602pst look like a texa thing
#   1:  joe park 62602pst origin messag from   s
#   1:  joe park 62602pst just sold 10000 mmbtu
#   1:  joe park 62602pst i am chang the follow
#   1:  joe park 62602pst updat robin and i are
#   1:  joe park 62602pst opp didnt mean to hit
#   1:  joe park 62602pst today we discov that e
#   1:  joe park 62602pst maragaret i have 2 pre
#   1:  joe park 62602pst updat on a new swing s
#   1:  joe park 62602pst noth so far joe park i
#   1:  joe park 62602pst updat ena was buy dail
#   1:  jpark nonprivilegedpst today we discov t
#   1:  jpark nonprivilegedpst updat robin and i
#   1:  jpark nonprivilegedpst i am chang the fo
#   1:  jpark nonprivilegedpst just sold 10000 m
#   1:  jpark nonprivilegedpst origin messag fro
#   1:  jpark nonprivilegedpst summari tdc energ
#   1:  jpark nonprivilegedpst there are 2 con e
#   1:  jpark nonprivilegedpst prepay for domini
#   1:  jpark nonprivilegedpst prepay and gas fl
#   1:  jpark nonprivilegedpst this is what i he
#   1:  jpark nonprivilegedpst per david walker
#   1:  spereir nonprivilegedpst our texa gas co
#   1:  vpimenov nonprivilegedpst fuel from prod
#   1:  kruscitnsf respons 1 ill let kevin answe
#   1:  kruscitnsf forward by  germanyhouect on
#   1:  kruscitnsf i have all of you set up in m
#   1:  kruscitnsf forward by  germanyhouect on
#   1:  kruscitnsf dkinneycolumbiaenergygroupcom
#   1:  kruscitnsf forward by  germanyhouect on
#   1:  kruscitnsf i have all of you set up in m
#   1:  kruscitnsf forward by  germanyhouect on
#   1:  kruscitnsf dkinneycolumbiaenergygroupcom
#   1:  kruscitnsf respons 1 ill let kevin answe
#   1:  kruscitnsf forward by  germanyhouect on
#   1:  kruscitnsf i have all of you set up in m
#   1:  kruscitnsf forward by  germanyhouect on
#   1:  storey geoffpst we sold the nation fuel
#   1:  storey geoffpst origin messag from   sen
#   1:  storey geoffpst i purchas 6172 day from
#   1:  jtownsensf on the 8th tp2 sold vng 10000
#   1:  jtownsensf httpgasmsgboardcorpenroncom
#   1:  jtownsensf current we are unabl to use i
#   1:  jtownsensf let me know what curv the fol
#   1:  judi townsend 62602pst i wonder if you g
#   1:  jtownsensf let me know what curv the fol
#   1:  jtownsensf current we are unabl to use i
#   1:  jtownsensf httpgasmsgboardcorpenroncom
#   1:  jtownsensf on the 8th tp2 sold vng 10000
#   1:  jtowns nonprivilegedpst origin messag fr
#   1:  jtowns nonprivilegedpst in septemb ena a
#   1:  jtowns nonprivilegedpst frank i was out
#   1:  jtowns nonprivilegedpst we have a discou
#   1:  jtowns nonprivilegedpst we have an disco
#   1:  jtowns nonprivilegedpst we negoti the fo
#   1:  judi townsend 62602pst richard jame tayl
#   1:  jtowns nonprivilegedpst i just know you
#   1:  jtowns nonprivilegedpst we have a discou
#   1:  jtowns nonprivilegedpst we are buy the f
#   1:  jtowns nonprivilegedpst i have a discoun
#   1:  judi townsend 62602pst i ask victor abou
#   1:  judi townsend 62602pst photo of my woman
#   1:  jtownsensf on the 8th tp2 sold vng 10000
#   1:  jtownsensf httpgasmsgboardcorpenroncom

# %% [markdown]
# ### Great job!
# Just for a check, what do you get for `word_data[152]`? I get
#
#     tjonesnsf stephani and sam need nymex calendar

# %% [markdown]
# ## Part 5 - TF-IDF
#
#
#
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/3/32/Las_Cruces.jpg" width="700"/>
#
# We are over the crest of the mountain and can see the cityscape of a structured representation!
# (okay, just a fancy way of saying we are over the hump)
# <img src="http://zacharski.org/files/courses/cs419/baylor.jpg" width="700"/>
#
# #### TF-IDF
# Transform the word_data into a tf-idf matrix using the sklearn TfIdf transformation. Remove english stopwords.
# You can access the mapping between words and feature numbers using get_feature_names(), which returns a list of all the words in the vocabulary.

# %% [markdown]
#  How many different words are there?  (You should get 38,757 unique words)

# %%
# Out:
# 38757

# %% [markdown]
# what is word number 34597? by that I mean the traditional computer science definition where there is word number 0.
#
#     stephaniethank

# %% [markdown]
# ## Part 6: divide the data into a training and test set
#
# When you do the split use the arguments:
#
#     test_size=0.1, random_state=42

# %% [markdown]
# How many entries are in the test set?  (I get 1758)

# %%
# Out:
# 1758

# %% [markdown]
# ## Part 7: Train a Classifier(SGBoost?) and use it to make predictions
#
# When you do the split use the arguments:

# %% [markdown]
# ### What is your accuracy?

# %%
# Out:
# 0.99146757679180886

# %% [markdown]
# # Finished!
